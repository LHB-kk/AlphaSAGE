# %%
import numpy as np
import os

from alphagen.data.expression import *
from alphagen.utils import reseed_everything
from alphagen_generic.features import *
from gan.utils.data import get_data_by_year

# %% [markdown]
# # Utility functions

# %%
import pandas as pd
from tqdm import tqdm
def get_ml_data(data):
    df = data.df_bak.copy()
    print(df.shape)
    print(df.columns)
    print("=" * 20)
    df.columns = ['open','close','high','low','volume', "vwap"]
    close_unstack = df['close'].unstack()
    tmp = (close_unstack.shift(-20)/close_unstack)-1
    label = tmp.stack().reindex(df.index)
    df['label'] = label

    feature = df[['open','close','high','low','volume',]]
    tmp = feature.unstack()
    feature = (tmp/tmp.shift(1)-1)#.stack().reindex(df.index)

    result_feature = []
    cur = feature.stack().reindex(df.index)
    cur.columns = [f'{col}0' for col in cur.columns]
    for past in tqdm(range(1,60)):
        cur = feature.shift(past).stack().reindex(df.index)
        cur.columns = [f'{col}{past}' for col in cur.columns]
        result_feature.append(cur)
    result_feature = pd.concat(result_feature,axis=1)
    df = pd.concat([result_feature,df['label']],axis=1)
    start_date = data._dates[data.max_backtrack_days]
    end_date = data._dates[-data.max_future_days]
    return df.loc[start_date:end_date]

def normalize_data(df_train, df_valid, df_test):
    # Get the column names of the features
    labels = [df_train.iloc[:, -1], df_valid.iloc[:, -1], df_test.iloc[:, -1]]
    df_train_features = df_train.iloc[:, :-1]
    df_valid_features = df_valid.iloc[:, :-1]
    df_test_features = df_test.iloc[:, :-1]

    _mean = df_train_features.mean()
    _std = df_train_features.std()
    print('1')
    df_train_norm = (df_train_features - _mean) / _std
    print('2')
    df_valid_norm = (df_valid_features - _mean) / _std
    print('3')
    df_test_norm = (df_test_features - _mean) / _std

    df_train_norm.fillna(0, inplace=True)
    df_valid_norm.fillna(0, inplace=True)
    df_test_norm.fillna(0, inplace=True)


    df_train_norm['label'] = np.nan_to_num(labels[0],nan=0,posinf=0,neginf=0)
    df_valid_norm['label'] = np.nan_to_num(labels[1],nan=0,posinf=0,neginf=0)
    df_test_norm['label'] = np.nan_to_num(labels[2],nan=0,posinf=0,neginf=0)

    df_train_norm['label'] = df_train_norm['label'].groupby('datetime').transform(lambda x: (x - x.mean()) / x.std()).clip(-4, 4)

    df_train_norm = df_train_norm.clip(-4, 4)
    df_valid_norm = df_valid_norm.clip(-4, 4)
    df_test_norm = df_test_norm.clip(-4, 4)

    return df_train_norm, df_valid_norm, df_test_norm

# %% [markdown]
# # Train LightGBM Model

# %%
import lightgbm as lgb
import pandas as pd

def train_lightgbm_model(df_train, df_valid, df_test):
    # Fill NaN values with 0
    df_train_filled = df_train.fillna(0)
    df_valid_filled = df_valid.fillna(0)
    df_test_filled = df_test.fillna(0)

    # Separate features and labels
    X_train = df_train_filled.drop(columns=['label'])
    y_train = df_train_filled['label']
    X_valid = df_valid_filled.drop(columns=['label'])
    y_valid = df_valid_filled['label']
    X_test = df_test_filled.drop(columns=['label'])
    y_test = df_test_filled['label']

    # Convert data to LightGBM Dataset format
    train_data = lgb.Dataset(X_train, label=y_train)
    valid_data = lgb.Dataset(X_valid, label=y_valid)

    # Set hyperparameters for LightGBM model
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'num_leaves': 128,
        'max_depth': 64,
        'learning_rate': 0.2,
        'feature_fraction': 0.9,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'verbose': 0
    }

    # Train the LightGBM model
    model = lgb.train(params, train_data, valid_sets=[train_data, valid_data], num_boost_round=100, callbacks=[lgb.early_stopping(100), lgb.log_evaluation(100)])

    # Evaluate the model on the test set
    y_pred = model.predict(X_test)
    
    pred = pd.concat([pd.Series(y_pred,index=df_test.index),df_test['label']],axis=1)
    # Print the RMSE score
    # rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    # print(f"RMSE: {rmse}")

    return  model,pred

for instruments in ['sp500']:
    for train_end in range(2016,2019):
        returned = get_data_by_year(
            train_start = 2010, train_end=train_end,valid_year=train_end+1,test_year =train_end+2,
            instruments=instruments, target=target,freq='day',
            qlib_path='/root/autodl-tmp/qlib_data/us_data'
            )
        data_all, data,data_valid,data_valid_withhead,data_test,data_test_withhead,_ = returned
        df_train = get_ml_data(data)
        df_valid = get_ml_data(data_valid)
        df_test = get_ml_data(data_test)
        df_train, df_valid, df_test = normalize_data(df_train, df_valid, df_test)
        
        model_name = 'lgbm'
        name = f"{instruments}_{model_name}_{train_end}"
        os.makedirs(f"out_ml/{name}",exist_ok=True)
        model,pred = train_lightgbm_model(df_train, df_valid, df_test)
        model.save_model(f"out_ml/{name}/{model_name}.pt")
        pred.to_pickle(f"out_ml/{name}/pred.pkl")
# Out:
# (806818, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   2%|▏         | 1/59 [00:00<00:07,  7.89it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   3%|▎         | 2/59 [00:00<00:07,  8.08it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:00<00:06,  8.50it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   7%|▋         | 4/59 [00:00<00:06,  8.48it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   8%|▊         | 5/59 [00:00<00:06,  8.36it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:00<00:06,  8.20it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  12%|█▏        | 7/59 [00:00<00:06,  8.00it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  14%|█▎        | 8/59 [00:00<00:06,  7.74it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  15%|█▌        | 9/59 [00:01<00:08,  6.06it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  17%|█▋        | 10/59 [00:01<00:08,  5.57it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  19%|█▊        | 11/59 [00:01<00:07,  6.20it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  20%|██        | 12/59 [00:01<00:06,  6.74it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  22%|██▏       | 13/59 [00:01<00:06,  7.15it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  24%|██▎       | 14/59 [00:01<00:05,  7.53it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  25%|██▌       | 15/59 [00:02<00:05,  7.53it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  27%|██▋       | 16/59 [00:02<00:05,  7.69it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  29%|██▉       | 17/59 [00:02<00:05,  7.81it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  31%|███       | 18/59 [00:02<00:05,  8.00it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  32%|███▏      | 19/59 [00:02<00:04,  8.07it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  34%|███▍      | 20/59 [00:02<00:04,  8.05it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  36%|███▌      | 21/59 [00:02<00:04,  8.16it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  37%|███▋      | 22/59 [00:02<00:04,  8.19it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  39%|███▉      | 23/59 [00:03<00:04,  8.30it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  41%|████      | 24/59 [00:03<00:04,  8.32it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  42%|████▏     | 25/59 [00:03<00:04,  8.35it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  44%|████▍     | 26/59 [00:03<00:03,  8.37it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  46%|████▌     | 27/59 [00:03<00:03,  8.45it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:03<00:03,  8.20it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  49%|████▉     | 29/59 [00:03<00:03,  8.18it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  51%|█████     | 30/59 [00:03<00:03,  8.30it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  53%|█████▎    | 31/59 [00:03<00:03,  8.32it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  54%|█████▍    | 32/59 [00:04<00:03,  8.42it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  56%|█████▌    | 33/59 [00:04<00:03,  8.45it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  58%|█████▊    | 34/59 [00:04<00:02,  8.46it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  61%|██████    | 36/59 [00:04<00:02,  9.23it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  63%|██████▎   | 37/59 [00:04<00:02,  9.40it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  66%|██████▌   | 39/59 [00:04<00:02,  9.78it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  69%|██████▉   | 41/59 [00:05<00:01, 10.02it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  73%|███████▎  | 43/59 [00:05<00:01, 10.14it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  76%|███████▋  | 45/59 [00:05<00:01,  8.47it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  78%|███████▊  | 46/59 [00:05<00:01,  7.51it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  80%|███████▉  | 47/59 [00:05<00:01,  7.93it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:06<00:01,  8.60it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  85%|████████▍ | 50/59 [00:06<00:01,  8.79it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  88%|████████▊ | 52/59 [00:06<00:00,  9.35it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  92%|█████████▏| 54/59 [00:06<00:00,  9.69it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  95%|█████████▍| 56/59 [00:06<00:00,  9.94it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  98%|█████████▊| 58/59 [00:06<00:00, 10.17it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:06<00:00,  8.45it/s]
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
# (183872, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  12%|█▏        | 7/59 [00:00<00:00, 66.34it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  24%|██▎       | 14/59 [00:00<00:00, 66.06it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  36%|███▌      | 21/59 [00:00<00:00, 66.56it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:00<00:00, 67.55it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  59%|█████▉    | 35/59 [00:00<00:00, 67.26it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:00<00:00, 61.80it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:00<00:00, 46.82it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  93%|█████████▎| 55/59 [00:01<00:00, 40.96it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:01<00:00, 50.97it/s]
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
# (406280, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:00<00:02, 23.72it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:00<00:02, 22.25it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# ...
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  36%|███▌      | 21/59 [00:00<00:00, 62.80it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:00<00:00, 62.93it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  59%|█████▉    | 35/59 [00:00<00:00, 63.48it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:00<00:00, 63.07it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:00<00:00, 64.21it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  95%|█████████▍| 56/59 [00:00<00:00, 65.01it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:00<00:00, 64.28it/s]
# 1
# 2
# 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.872155	valid_1's rmse: 0.139675
# Did not meet early stopping. Best iteration is:
# [1]	training's rmse: 0.925819	valid_1's rmse: 0.0790909

# %% [markdown]
# # Train XGBoost Model

# %%
import xgboost as xgb
import pandas as pd

def train_xgboost_model(df_train, df_valid, df_test):
    # Fill NaN values with 0
    df_train_filled = df_train.fillna(0)
    df_valid_filled = df_valid.fillna(0)
    df_test_filled = df_test.fillna(0)

    # Separate features and labels
    X_train = df_train_filled.drop(columns=['label'])
    y_train = df_train_filled['label']
    X_valid = df_valid_filled.drop(columns=['label'])
    y_valid = df_valid_filled['label']
    X_test = df_test_filled.drop(columns=['label'])
    y_test = df_test_filled['label']

    # Convert data to DMatrix format
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dvalid = xgb.DMatrix(X_valid, label=y_valid)

    # Set hyperparameters for XGBoost model
    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'colsample_bytree': 0.8879,
        'learning_rate': 0.01,
        'subsample': 0.8789,
        'lambda': 205.6999,
        'alpha': 580.9768,
        'max_depth': 4,
        'num_boost_round': 100,
        'early_stopping_rounds': 100,
        'verbose_eval': 100
    }

    # Train the XGBoost model
    model = xgb.train(params, dtrain, evals=[(dtrain, 'train'), (dvalid, 'valid')], early_stopping_rounds=params['early_stopping_rounds'], verbose_eval=params['verbose_eval'])

    # Convert test data to DMatrix format
    dtest = xgb.DMatrix(X_test)

    # Make predictions on the test set
    y_pred = model.predict(dtest)

    # Combine the predictions with the actual labels
    # pred = pd.concat([df_test['label'], pd.Series(y_pred, index=df_test.index)], axis=1)
    pred = pd.concat([pd.Series(y_pred,index=df_test.index),df_test['label']],axis=1)

    return model, pred



for instruments in ['sp500']:
    for train_end in range(2016,2019):
        returned = get_data_by_year(
            train_start = 2010,train_end=train_end,valid_year=train_end+1,test_year =train_end+2,
            instruments=instruments, target=target,freq='day',
            qlib_path='/root/autodl-tmp/qlib_data/us_data'
            )
        data_all, data,data_valid,data_valid_withhead,data_test,data_test_withhead,_ = returned
        df_train = get_ml_data(data)
        df_valid = get_ml_data(data_valid)
        df_test = get_ml_data(data_test)
        df_train, df_valid, df_test = normalize_data(df_train, df_valid, df_test)
        
        model_name = 'xgb'
        name = f"{instruments}_{model_name}_{train_end}"
        os.makedirs(f"out_ml/{name}",exist_ok=True)
        model,pred = train_xgboost_model(df_train, df_valid, df_test)
        model.save_model(f"out_ml/{name}/{model_name}.pt")
        pred.to_pickle(f"out_ml/{name}/pred.pkl")
# Out:
# (806818, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   2%|▏         | 1/59 [00:00<00:09,  6.30it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   3%|▎         | 2/59 [00:00<00:08,  6.74it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:00<00:08,  6.75it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   7%|▋         | 4/59 [00:00<00:08,  6.82it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   8%|▊         | 5/59 [00:00<00:07,  6.81it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:00<00:07,  6.91it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  12%|█▏        | 7/59 [00:01<00:07,  7.08it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  14%|█▎        | 8/59 [00:01<00:07,  7.14it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  15%|█▌        | 9/59 [00:01<00:07,  6.77it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  17%|█▋        | 10/59 [00:01<00:07,  6.42it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  19%|█▊        | 11/59 [00:01<00:07,  6.35it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  20%|██        | 12/59 [00:01<00:07,  6.45it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  22%|██▏       | 13/59 [00:01<00:06,  6.65it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  24%|██▎       | 14/59 [00:02<00:06,  6.93it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  25%|██▌       | 15/59 [00:02<00:06,  6.81it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  27%|██▋       | 16/59 [00:02<00:06,  6.99it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  29%|██▉       | 17/59 [00:02<00:05,  7.10it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  31%|███       | 18/59 [00:02<00:05,  7.21it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  32%|███▏      | 19/59 [00:02<00:05,  7.43it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  34%|███▍      | 20/59 [00:02<00:05,  7.64it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  36%|███▌      | 21/59 [00:02<00:04,  7.75it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  37%|███▋      | 22/59 [00:03<00:04,  7.94it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  39%|███▉      | 23/59 [00:03<00:04,  8.08it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  41%|████      | 24/59 [00:03<00:04,  8.16it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  42%|████▏     | 25/59 [00:03<00:04,  8.22it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  44%|████▍     | 26/59 [00:03<00:04,  8.16it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  46%|████▌     | 27/59 [00:03<00:03,  8.16it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:03<00:03,  7.75it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  49%|████▉     | 29/59 [00:04<00:03,  7.62it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  51%|█████     | 30/59 [00:04<00:03,  7.85it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  53%|█████▎    | 31/59 [00:04<00:03,  7.97it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  54%|█████▍    | 32/59 [00:04<00:03,  7.84it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  56%|█████▌    | 33/59 [00:04<00:03,  8.04it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  58%|█████▊    | 34/59 [00:04<00:03,  8.03it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  59%|█████▉    | 35/59 [00:04<00:02,  8.02it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  61%|██████    | 36/59 [00:04<00:02,  7.90it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  63%|██████▎   | 37/59 [00:04<00:02,  8.05it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  64%|██████▍   | 38/59 [00:05<00:02,  8.16it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  66%|██████▌   | 39/59 [00:05<00:02,  8.07it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  68%|██████▊   | 40/59 [00:05<00:02,  8.00it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  69%|██████▉   | 41/59 [00:05<00:02,  8.06it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:05<00:02,  8.15it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  73%|███████▎  | 43/59 [00:05<00:01,  8.08it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  75%|███████▍  | 44/59 [00:05<00:01,  8.17it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  76%|███████▋  | 45/59 [00:05<00:01,  8.30it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  78%|███████▊  | 46/59 [00:06<00:01,  8.28it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  80%|███████▉  | 47/59 [00:06<00:01,  8.41it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  81%|████████▏ | 48/59 [00:06<00:01,  8.43it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:06<00:01,  8.46it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  85%|████████▍ | 50/59 [00:06<00:01,  8.44it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  86%|████████▋ | 51/59 [00:06<00:00,  8.13it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  88%|████████▊ | 52/59 [00:06<00:00,  7.97it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  90%|████████▉ | 53/59 [00:06<00:00,  7.87it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  92%|█████████▏| 54/59 [00:07<00:00,  7.79it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  93%|█████████▎| 55/59 [00:07<00:00,  7.76it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  95%|█████████▍| 56/59 [00:07<00:00,  7.74it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  97%|█████████▋| 57/59 [00:07<00:00,  7.75it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  98%|█████████▊| 58/59 [00:07<00:00,  7.82it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:07<00:00,  7.64it/s]
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
# (183872, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:00<00:00, 54.77it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  20%|██        | 12/59 [00:00<00:00, 54.64it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  31%|███       | 18/59 [00:00<00:00, 53.44it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  41%|████      | 24/59 [00:00<00:00, 54.13it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  51%|█████     | 30/59 [00:00<00:00, 53.84it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  61%|██████    | 36/59 [00:00<00:00, 54.42it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:00<00:00, 54.38it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  81%|████████▏ | 48/59 [00:00<00:00, 54.22it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  92%|█████████▏| 54/59 [00:00<00:00, 54.53it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:01<00:00, 54.52it/s]
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
# (406280, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:00<00:02, 26.49it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
# ...
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  31%|███       | 18/59 [00:00<00:00, 54.78it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  41%|████      | 24/59 [00:00<00:00, 55.65it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  51%|█████     | 30/59 [00:00<00:00, 56.79it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  61%|██████    | 36/59 [00:00<00:00, 57.74it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  73%|███████▎  | 43/59 [00:00<00:00, 58.71it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  85%|████████▍ | 50/59 [00:00<00:00, 59.66it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  97%|█████████▋| 57/59 [00:00<00:00, 60.73it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:01<00:00, 58.44it/s]
# 1
# 2
# 3
# /root/miniconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [18:27:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "early_stopping_rounds", "num_boost_round", "verbose_eval" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	train-rmse:0.92681	valid-rmse:0.07773
# [9]	train-rmse:0.92678	valid-rmse:0.07772
# /tmp/ipykernel_34086/3794869412.py:71: UserWarning: [18:27:59] WARNING: /workspace/src/c_api/c_api.cc:1575: Saving model in the UBJSON format as default.  You can use a file extension: `json` or `ubj` to choose between formats.
#   model.save_model(f"out_ml/{name}/{model_name}.pt")

# %% [markdown]
# # Train MLP Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def train_mlp_model(df_train, df_valid, df_test):
    # Fill NaN values with 0
    df_train_filled = df_train.fillna(0)
    df_valid_filled = df_valid.fillna(0)
    df_test_filled = df_test.fillna(0)

    # Separate features and labels
    X_train = df_train_filled.drop(columns=['label']).values
    y_train = df_train_filled['label'].values
    X_valid = df_valid_filled.drop(columns=['label']).values
    y_valid = df_valid_filled['label'].values
    X_test = df_test_filled.drop(columns=['label']).values
    y_test = df_test_filled['label'].values

    # Convert data to tensors
    X_train = torch.tensor(X_train, dtype=torch.float32)
    y_train = torch.tensor(y_train, dtype=torch.float32)
    X_valid = torch.tensor(X_valid, dtype=torch.float32)
    y_valid = torch.tensor(y_valid, dtype=torch.float32)
    X_test = torch.tensor(X_test, dtype=torch.float32)
    y_test = torch.tensor(y_test, dtype=torch.float32)

    # Define the MLP model
    model = nn.Sequential(
        nn.Linear(X_train.shape[1], 32),
        nn.ReLU(),
        nn.Linear(32, 1)
    )

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.01)


    # Move the model to GPU if available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Train the model
    num_epochs = 2
    batch_size = 512
    for epoch in range(num_epochs):
        # Shuffle the training data
        indices = torch.randperm(X_train.shape[0])
        X_train_shuffled = X_train[indices]
        y_train_shuffled = y_train[indices]

        # Mini-batch training
        for i in tqdm(range(0, X_train.shape[0], batch_size)):
            # Get the mini-batch
            X_batch = X_train_shuffled[i:i+batch_size]
            y_batch = y_train_shuffled[i:i+batch_size]

            # Move the mini-batch to GPU if available
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            # Forward pass
            outputs = model(X_batch)
            loss = criterion(outputs.flatten(), y_batch.flatten())

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # Evaluate the model on the test set
    with torch.no_grad():
        # Move the test data to GPU if available
        test_outputs = model(X_test.to(device)).detach().cpu().numpy().flatten()
        pred_df = pd.concat([df_test['label'],pd.Series(test_outputs,index=df_test.index)],axis=1)
    torch.cuda.empty_cache()
    return model, pred_df

for instruments in ['sp500']:
    for train_end in range(2016,2019):
        returned = get_data_by_year(
            train_start = 2010,train_end=train_end,valid_year=train_end+1,test_year =train_end+2,
            instruments=instruments, target=target,freq='day',)
        data_all, data,data_valid,data_valid_withhead,data_test,data_test_withhead,_ = returned
        df_train = get_ml_data(data)
        df_valid = get_ml_data(data_valid)
        df_test = get_ml_data(data_test)
        df_train, df_valid, df_test = normalize_data(df_train, df_valid, df_test)
        for seed in range(1):
            reseed_everything(seed)
            model_name = 'mlp'
            name = f"{instruments}_{model_name}_{train_end}"
            os.makedirs(f"out_ml/{name}",exist_ok=True)
            model,pred = train_mlp_model(df_train, df_valid, df_test)
            # model.save_model(f"out_ml/{name}/model.pt")
            pred.to_pickle(f"out_ml/{name}/pred_{seed}.pkl")
# Out:
# (806818, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   2%|▏         | 1/59 [00:00<00:06,  8.59it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   3%|▎         | 2/59 [00:00<00:06,  8.74it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:00<00:06,  8.74it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   7%|▋         | 4/59 [00:00<00:06,  8.76it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   8%|▊         | 5/59 [00:00<00:06,  8.64it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:00<00:06,  8.73it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  12%|█▏        | 7/59 [00:00<00:05,  8.82it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  14%|█▎        | 8/59 [00:00<00:05,  8.91it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  15%|█▌        | 9/59 [00:01<00:05,  8.95it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  17%|█▋        | 10/59 [00:01<00:05,  8.81it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  19%|█▊        | 11/59 [00:01<00:05,  8.88it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  20%|██        | 12/59 [00:01<00:05,  8.89it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  22%|██▏       | 13/59 [00:01<00:05,  8.87it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  24%|██▎       | 14/59 [00:01<00:05,  8.86it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  25%|██▌       | 15/59 [00:01<00:04,  8.86it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  27%|██▋       | 16/59 [00:01<00:04,  8.83it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  29%|██▉       | 17/59 [00:01<00:04,  8.85it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  31%|███       | 18/59 [00:02<00:04,  8.68it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  32%|███▏      | 19/59 [00:02<00:04,  8.85it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  34%|███▍      | 20/59 [00:02<00:04,  8.88it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  36%|███▌      | 21/59 [00:02<00:04,  8.83it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  37%|███▋      | 22/59 [00:02<00:04,  8.82it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  39%|███▉      | 23/59 [00:02<00:04,  8.85it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  41%|████      | 24/59 [00:02<00:03,  8.82it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  42%|████▏     | 25/59 [00:02<00:03,  8.83it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  44%|████▍     | 26/59 [00:02<00:03,  8.85it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  46%|████▌     | 27/59 [00:03<00:03,  8.88it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:03<00:03,  8.89it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  49%|████▉     | 29/59 [00:03<00:03,  8.90it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  51%|█████     | 30/59 [00:03<00:03,  8.92it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  53%|█████▎    | 31/59 [00:03<00:03,  8.93it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  54%|█████▍    | 32/59 [00:03<00:03,  8.94it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  56%|█████▌    | 33/59 [00:03<00:02,  8.95it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  58%|█████▊    | 34/59 [00:03<00:02,  8.94it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  59%|█████▉    | 35/59 [00:03<00:02,  8.97it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  61%|██████    | 36/59 [00:04<00:02,  9.04it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  63%|██████▎   | 37/59 [00:04<00:02,  9.08it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  64%|██████▍   | 38/59 [00:04<00:02,  9.11it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  66%|██████▌   | 39/59 [00:04<00:02,  9.14it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  68%|██████▊   | 40/59 [00:04<00:02,  9.24it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:04<00:01,  9.96it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  73%|███████▎  | 43/59 [00:04<00:01,  9.55it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  75%|███████▍  | 44/59 [00:04<00:01,  9.39it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  76%|███████▋  | 45/59 [00:05<00:01,  9.25it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  78%|███████▊  | 46/59 [00:05<00:01,  9.15it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  80%|███████▉  | 47/59 [00:05<00:01,  9.07it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  81%|████████▏ | 48/59 [00:05<00:01,  9.03it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:05<00:01,  9.03it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  85%|████████▍ | 50/59 [00:05<00:01,  8.99it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  86%|████████▋ | 51/59 [00:05<00:00,  9.04it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  88%|████████▊ | 52/59 [00:05<00:00,  9.06it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  90%|████████▉ | 53/59 [00:05<00:00,  9.03it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  92%|█████████▏| 54/59 [00:06<00:00,  8.99it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  93%|█████████▎| 55/59 [00:06<00:00,  9.02it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  95%|█████████▍| 56/59 [00:06<00:00,  9.03it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  97%|█████████▋| 57/59 [00:06<00:00,  9.05it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  98%|█████████▊| 58/59 [00:06<00:00,  9.05it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:06<00:00,  8.98it/s]
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
# (183872, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:00<00:01, 50.60it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  20%|██        | 12/59 [00:00<00:00, 49.16it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  29%|██▉       | 17/59 [00:00<00:00, 49.24it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  37%|███▋      | 22/59 [00:00<00:00, 48.98it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  46%|████▌     | 27/59 [00:00<00:00, 49.24it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  54%|█████▍    | 32/59 [00:00<00:00, 49.13it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  63%|██████▎   | 37/59 [00:00<00:00, 49.21it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:00<00:00, 49.28it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  81%|████████▏ | 48/59 [00:00<00:00, 49.90it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  90%|████████▉ | 53/59 [00:01<00:00, 49.87it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:01<00:00, 49.71it/s]
# /tmp/ipykernel_34086/1516953438.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
# (406280, 6)
# Index(['$open', '$close', '$high', '$low', '$volume', '$vwap'], dtype='object')
# ====================
#   0%|          | 0/59 [00:00<?, ?it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:00<00:02, 23.29it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
# ...
#   cur = feature.shift(past).stack().reindex(df.index)
#  27%|██▋       | 16/59 [00:00<00:01, 34.71it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  34%|███▍      | 20/59 [00:00<00:01, 35.47it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  41%|████      | 24/59 [00:00<00:00, 36.03it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:00<00:00, 36.55it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  54%|█████▍    | 32/59 [00:00<00:00, 36.88it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  61%|██████    | 36/59 [00:00<00:00, 36.76it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  69%|██████▉   | 41/59 [00:01<00:00, 39.04it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  76%|███████▋  | 45/59 [00:01<00:00, 38.73it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:01<00:00, 38.92it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  92%|█████████▏| 54/59 [00:01<00:00, 37.19it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# /tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  98%|█████████▊| 58/59 [00:01<00:00, 37.70it/s]/tmp/ipykernel_34086/1516953438.py:22: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:01<00:00, 37.32it/s]
# 1
# 2
# 3
# 100%|██████████| 1951/1951 [00:06<00:00, 316.12it/s]
# 100%|██████████| 1951/1951 [00:05<00:00, 325.71it/s]

# %% [markdown]
# # Show LightGBM Resuls

# %%
import pandas as pd
from alphagen.utils.correlation import batch_pearsonr, batch_spearmanr, batch_ret, batch_sharpe_ratio, batch_max_drawdown
import torch
import os
import numpy as np

def chunk_batch_spearmanr(x, y, chunk_size=100):
    n_days = len(x)
    spearmanr_list= []
    for i in range(0, n_days, chunk_size):
        spearmanr_list.append(batch_spearmanr(x[i:i+chunk_size], y[i:i+chunk_size]))
    spearmanr_list = torch.cat(spearmanr_list, dim=0)
    return spearmanr_list

def get_tensor_metrics(x, y, risk_free_rate=0.0):
    # Ensure tensors are 2D (days, stocks)
    if x.dim() > 2: x = x.squeeze(-1)
    if y.dim() > 2: y = y.squeeze(-1)

    ic_s = batch_pearsonr(x, y)
    ric_s = chunk_batch_spearmanr(x, y, chunk_size=400)
    ret_s = batch_ret(x, y) - 0.001

    ic_s = torch.nan_to_num(ic_s, nan=0.)
    ric_s = torch.nan_to_num(ric_s, nan=0.)
    ret_s = torch.nan_to_num(ret_s, nan=0.) / 20
    ic_s_mean = ic_s.mean().item()
    ic_s_std = ic_s.std().item() if ic_s.std().item() > 1e-6 else 1.0
    ric_s_mean = ric_s.mean().item()
    ric_s_std = ric_s.std().item() if ric_s.std().item() > 1e-6 else 1.0
    ret_s_mean = ret_s.mean().item()
    ret_s_std = ret_s.std().item() if ret_s.std().item() > 1e-6 else 1.0
    
    # Calculate Sharpe Ratio and Maximum Drawdown for ret series
    ret_sharpe = batch_sharpe_ratio(ret_s, risk_free_rate).item()
    ret_mdd = batch_max_drawdown(ret_s).item()
    result = dict(
        ic=ic_s_mean,
        ic_std=ic_s_std,
        icir=ic_s_mean / ic_s_std,
        ric=ric_s_mean,
        ric_std=ric_s_std,
        ricir=ric_s_mean / ric_s_std,
        ret=ret_s_mean * len(ret_s) / 3,
        ret_std=ret_s_std,
        retir=ret_s_mean / ret_s_std,
        ret_sharpe=ret_sharpe,
        ret_mdd=ret_mdd,
    )
    return result, ret_s

# %%
instruments = 'sp500'

result = []
for year in range(2016,2019):
    result.append(pd.read_pickle(f'out_ml/{instruments}_lgbm_{year}/pred.pkl'))
df = pd.concat(result,axis=0)
data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
pred = data[0].values
label = data["label"].values
res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
print(pd.DataFrame(res,index=['Test']))
save_path = os.path.join(f'out_ml/{instruments}_lgbm_{year}', 'ret_s.npy')
np.save(save_path, ret_s)
# Out:
#             ic    ic_std     icir       ric   ric_std     ricir       ret  \
# Test  0.004853  0.086469  0.05613  0.010677  0.098534  0.108357  0.070479
#
#        ret_std     retir  ret_sharpe   ret_mdd
# Test  0.003538  0.086353    1.370818  0.270489

# %% [markdown]
# # Show XGBoost Result

# %%
import pandas as pd
instruments = 'sp500'

result = []
for year in range(2016,2019):
    result.append(pd.read_pickle(f'out_ml/{instruments}_xgb_{year}/pred.pkl'))
df = pd.concat(result,axis=0)

data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
pred = data[0].values
label = data["label"].values
res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
print(pd.DataFrame(res,index=['Test']))
save_path = os.path.join(f'out_ml/{instruments}_xgb_{year}', 'ret_s.npy')
np.save(save_path, ret_s)
# Out:
#             ic    ic_std      icir       ric  ric_std     ricir       ret  \
# Test  0.006419  0.067796  0.094688  0.022928  0.13717  0.167149  0.086828
#
#        ret_std     retir  ret_sharpe   ret_mdd
# Test  0.003185  0.118167    1.875848  0.245043

# %% [markdown]
# # Show MLP Result

# %%
import pandas as pd
result_all = []
instruments = 'sp500'
for seed in range(1):
    result = []
    for year in range(2016,2019):
        result.append(pd.read_pickle(f'out_ml/{instruments}_mlp_{year}/pred_{seed}.pkl'))
    df = pd.concat(result,axis=0)#.groupby('datetime').corr('spearman')['label'].unstack().mean()
    data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
    pred = data[0].values
    label = data["label"].values
    res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
    print(pd.DataFrame(res,index=['Test']))
    save_path = os.path.join(f'out_ml/{instruments}_mlp_{year}', 'ret_s.npy')
    np.save(save_path, ret_s)
# Out:
#             ic   ic_std      icir       ric   ric_std     ricir       ret  \
# Test  0.002336  0.01946  0.120028  0.001861  0.078194  0.023804  0.063151
#
#        ret_std     retir  ret_sharpe   ret_mdd
# Test  0.003614  0.075752    1.202531  0.278508
